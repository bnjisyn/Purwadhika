# %% [markdown]
# > Benjamin Nikholas
#
# > Data Science / JCSDOL-014
#
# > Modul 2 - Tugas 25
#
# > 18 Juni 2024
# ---
# ---

# %% [markdown]
# # Exercise: Data Visualization
# - Tampilkan visualisasi yang sesuai
# - Berikan insightnya

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Sample - Superstore.xlsx', sheet_name='Orders')
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
#  17  Sales           9994 non-null   float64
#  18  Quantity        9994 non-null   int64
#  19  Discount        9994 non-null   float64
#  20  Profit          9994 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(13)
# memory usage: 1.6+ MB

# %% [markdown]
# ### **No.1**
#
# Tampilkan distribusi Sales

# %%
plt.hist(df['Sales'], bins = 2)
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **No.2**
#
# Apakah ada outliers di variable Sales? Di nilai berapa nilai Sales dianggap outliers?

# %%
Q1 = df.Sales.quantile(0.25)
Q3 = df.Sales.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.Sales < lower_bound) | (df.Sales > upper_bound)]

# %%
mean_sales = df.Sales.mean()
std_sales = df.Sales.std()

print(f'Terdapat Outlier di kolom Sales berjumlah {len(outliers)} dan dianggap outlier jika berada dibawah angka {lower_bound:.2f} atau diatas {upper_bound:.2f}')
# Out:
# Terdapat Outlier di kolom Sales berjumlah 1167 dan dianggap outlier jika berada dibawah angka -271.71 atau diatas 498.93

# %% [markdown]
# ### **No.3**
#
# Tampilkan total profit tiap Category

# %%
total_profit = pd.DataFrame(df.groupby('Category').Profit.sum())
total_profit

# total_profit.plot(kind = 'bar')
plt.bar(total_profit.index, total_profit.Profit)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### **No.4**
#
# Tampilkan total profit tiap Segment yang dibagi lagi per Category

# %%
pivot = pd.pivot_table(df, 
                       values = 'Profit',
                    #    index = 'Segment',
                       index = ['Segment', 'Category'],
                    #    columns = 'Category',
                       aggfunc = 'sum')
pivot
# Out:
#                                  Profit
# Segment     Category
# Consumer    Furniture         6991.0786
#             Office Supplies  56330.3210
#             Technology       70797.8096
# Corporate   Furniture         7584.8158
#             Office Supplies  40227.3202
#             Technology       44166.9980
# Home Office Furniture         3875.3784
#             Office Supplies  25933.1596
#             Technology       30490.1405

# %% [markdown]
# ### **No.5**
#
# Apakah ada hubungan antara Discount dan Profit?

# %%
print(f'Besaran Korelasi antara Discount dan Profit = {df.Discount.corr(df.Profit)}')

plt.scatter(x = df.Discount, y = df.Profit)
plt.show()
# Out:
# Besaran Korelasi antara Discount dan Profit = -0.21948745637176836

# %% [markdown]
# Kolom Discount dan Profit memiliki hubungan terbalik dengan tingkat korelasi rendah

# %% [markdown]
# ### **No.6**
#
# Tampilkan total profit tiap bulan dari 2016-2019

# %%
df['Month Name'] = df['Order Date'].dt.strftime('%B')

month_order = ['January', 'February', 'March', 'April', 
               'May', 'June', 'July', 'August', 
               'September', 'October', 'November', 'December']

df['Month Name'] = pd.Categorical(df['Month Name'], 
                                  categories = month_order, 
                                  ordered = True)

# %%
pivot = pd.pivot_table(df, 
                       values = 'Profit',
                     #   index = [df['Order Date'].dt.year, df['Order Date'].dt.month],
                     #   index = [df['Order Date'].dt.year, df['Order Date'].dt.strftime('%B')],
                       index = [df['Order Date'].dt.year],
                       columns = ['Month Name'],
                       aggfunc = 'sum')
pivot
# Out:
# Month Name    January   February       March      April        May       June  \
# Order Date
# 2016        2450.1907   862.3084    498.7299  3488.8352  2738.7096  4976.5244
# 2017       -3281.0070  2813.8508   9732.0978  4187.4962  4667.8690  3335.5572
# 2018        2824.8233  5004.5795   3611.9680  2977.8149  8662.1464  4750.3781
# 2019        7140.4391  1613.8720  14751.8915   933.2900  6342.5828  8223.3357
#
# Month Name       July     August   September     October    November  \
# Order Date
# 2016        -841.4826  5318.1050   8328.0994   3448.2573   9292.1269
# 2017        3288.6483  5355.8084   8209.1627   2817.3660  12474.7884
# 2018        4432.8779  2062.0693   9328.6576  16243.1425   4011.4075
# 2019        6952.6212  9040.9557  10991.5556   9275.2755   9690.1037
#
# Month Name    December
# Order Date
# 2016         8983.5699
# 2017         8016.9659
# 2018        17885.3093
# 2019         8483.3468

# %% [markdown]
# ### **No.7**
#
# Bandingkan trend profit pada tanggal 15 dan tanggal 28 dari tiap bulan

# %%
df_15_28 = df[(df['Order Date'].dt.day == 15) | (df['Order Date'].dt.day == 28)]

pivot = pd.pivot_table(df_15_28,
                       values = 'Profit',
                       index = ['Month Name'],
                       columns = [df['Order Date'].dt.day],
                       aggfunc = 'sum')
pivot
# Out:
# Order Date         15         28
# Month Name
# January      559.3064 -1516.8221
# February     612.6148    50.3634
# March         96.6325   118.7906
# April        280.9024  2322.9480
# May          345.6765   778.1304
# June         360.2515   110.6501
# July         358.9474 -1164.3182
# August       112.7735  1675.8054
# September   3106.8424   336.2429
# October      496.0678   421.4209
# November     680.5589   780.3894
# December   -1589.0133   962.8868
