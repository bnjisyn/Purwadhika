# %% [markdown]
# > Benjamin Nikholas
#
# > Data Science / JCSDOL-014
#
# > Modul 3 - Tugas 18
#
# > 16 Juli 2024
# ---
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('melb_data.csv')
df
# Out:
#                 Suburb           Address  Rooms Type      Price Method  \
# 0           Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           Abbotsford       55a Park St      4    h  1600000.0     VB
# ...                ...               ...    ...  ...        ...    ...
# 10194  Caulfield North   641 Inkerman Rd      2    h  1417500.0      S
# 10195  Caulfield South       14 Stone St      4    h  1550000.0      S
# 10196        Chadstone  2/15 Atkinson St      2    h   510000.0     PI
# 10197       Cheltenham      1 Dewrang St      3    h  1010000.0     SA
# 10198       Cheltenham    1/21 Kayden St      2    u   601000.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0
# 1             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 2             Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# 3             Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0
# 4             Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 10194       Marshall  27/05/2017       7.8    3161.0  ...       1.0  2.0
# 10195  hockingstuart  27/05/2017       8.7    3162.0  ...       1.0  2.0
# 10196       Woodards  27/05/2017      11.7    3148.0  ...       1.0  2.0
# 10197         Hodges  27/05/2017      17.9    3192.0  ...       1.0  2.0
# 10198         Buxton  27/05/2017      17.9    3192.0  ...       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0         202.0           NaN        NaN        Yarra -37.79960   144.99840
# 1         156.0          79.0     1900.0        Yarra -37.80790   144.99340
# 2         134.0         150.0     1900.0        Yarra -37.80930   144.99440
# 3          94.0           NaN        NaN        Yarra -37.79690   144.99690
# 4         120.0         142.0     2014.0        Yarra -37.80720   144.99410
# ...         ...           ...        ...          ...       ...         ...
# 10194     307.0         103.0     1900.0    Glen Eira -37.86906   145.01986
# 10195     584.0           NaN        NaN    Glen Eira -37.89694   145.02176
# 10196     897.0          66.0     1970.0       Monash -37.88321   145.09594
# 10197     532.0           NaN        NaN     Kingston -37.95746   145.06706
# 10198    1078.0          94.0     1972.0            K       NaN         NaN
#
#                   Regionname Propertycount
# 0      Northern Metropolitan        4019.0
# 1      Northern Metropolitan        4019.0
# 2      Northern Metropolitan        4019.0
# 3      Northern Metropolitan        4019.0
# 4      Northern Metropolitan        4019.0
# ...                      ...           ...
# 10194  Southern Metropolitan        6923.0
# 10195  Southern Metropolitan        5051.0
# 10196  Southern Metropolitan        3582.0
# 10197  Southern Metropolitan        9758.0
# 10198                    NaN           NaN
#
# [10199 rows x 21 columns]
