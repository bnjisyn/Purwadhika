# %% [markdown]
# MindMap ML - Framework - step by step
#
# # Data & Bussines Understanding
# ** Domain Knowledge - bussines knowledge
#
# - define problem - bussines problem
# - define goal
# - define bussines quesions (opsional)
#
# - Data collection
# - Deskripsi features dan target (data)
#
# ## data exploration - data wranglong - EDA
# - cek data type
# - describe data
# - cek anomali data
#     - Cek Missing Value
#     - cek duplikat data
#     - cek outliers data
#
# # Data Analysis - Data Visualization
#
# ** Data analysis
# - analysis Univariate
# - analysis Multivariate
# - insight
#
# ** Data Visualization
# - analysis Univariate
# - analysis Multivariate
# - insight
#
# ## Machine Learning
#
# ** Data Preparation
# ----> Feature Engginering & atau Feature Selection
# Optional : Encoding
# --> cek korelasi data ==> tujuannya opsi untuk melakukan Feature Selection ==> Cek korelasi, uji statistik, menggunakan model algoritma, Based On EDA, Domain Knowledges (ini dipake ketika ada expert bisnis, nanti mrk yg nentuin kolom2 apa yg dipake untk model nya)
# - optional : cek asosiasi ==> itu sama seperti korelasi, hanya untuk data kategorikal | kalo data numerik itu pake koralsi pearson / spearman ==> untuk feature selection
# - optional : adding features  ==> cross features ==> features extraction
# adding feature = (ini sama kayak ngambil satu2 kolom tanggal)
# cross features = (ini seperti male maried, female single)
# - optional : Binning / Re-categorize
# - optinal : Transform
# - opsional : Scaling
#
# -----> Feature Selection ==> memilih features yg akan digunakn ketika training nmodel ML
#
# --> ML modellong
# - Spliting data
# - optional : Imbalance handling
# - Training Model --> base model (.fit())
# - Evaluation metriks base model untuk Benchmark/tolak ukur ,
# - optional : Tuning manual
# - optional : coba algoritma lain
# - evaluation metrics comparison (eva matrik antar base model dg yg sudah diTuning atu dg yg sudah di feature engginering)
# kalo tuning yg diotak atik itu ML nya
# kalo feature engginering ya feature nya
# - analisa error : penyebab error --> karakteristik data yg bikin error tinggi
# - Fine Tuning - Hyper parameter tuning
# - eva metrics after  hyper parameter Tuning
# - Eva metrics comparison
# - export model
#
# ----> Conclusion
# - Kesimpulan
# - Saran n Rekomendasi
