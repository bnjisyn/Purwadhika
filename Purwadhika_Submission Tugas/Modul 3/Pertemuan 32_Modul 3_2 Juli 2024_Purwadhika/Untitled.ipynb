# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Telco.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
pd.to_numeric(df['TotalCharges'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.to_numeric(df['TotalCharges'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
# ...

# %%
df.iloc[[488]]
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488  4472-LVYGI  Female              0     Yes        Yes       0
#
#     PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 488           No  No phone service             DSL            Yes  ...
#
#     DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 488              Yes         Yes         Yes              No  Two year
#
#     PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 488              Yes  Bank transfer (automatic)          52.55
#
#     Churn
# 488    No
#
# [1 rows x 21 columns]

# %%
df.drop(488, inplace=True)

# %%
len(df)
# Out:
# 7032

# %%
df[df['TotalCharges'] == ' ']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 753           Yes                No              No  No internet service  ...
# ...

# %%
df = df[df['TotalCharges'] != ' ']
## Handle Data Formatting

# %%
pd.to_numeric(df['TotalCharges'])
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'])
## Mengubah Tipe data menjadi Numerik

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.groupby('gender') ## Kolom yg digunakan dalam Group By harus Kategorikal (Diskrit)

# %%
df.groupby('gender').mean()
## Gunakan fungsi Agregasi data sesuai dg kebutuhan
## Ketika menggunakan Fungsi agregat, Seluruh kolom selain Kolom group by akan di kalkulasi
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
df.groupby('gender').mean(numeric_only=True) ## penggunaan parameter numeric_only => agar yg dilakukan fungsi agregasi Hanya kolom numerik
# Out:
#         SeniorCitizen     tenure  MonthlyCharges  TotalCharges
# gender
# Female       0.163078  32.290841       65.216652   2283.190985
# Male         0.161736  32.550296       64.387546   2283.407861

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.pivot_table(index='gender', values=['SeniorCitizen','tenure','MonthlyCharges', 'TotalCharges'], aggfunc='median')
### menggunakan fungsi Default ==> Fungsi default dari Pivot_table => Mean
# Out:
#         MonthlyCharges  SeniorCitizen  TotalCharges  tenure
# gender
# Female           70.65              0       1387.35      29
# Male             70.10              0       1404.65      29

# %%
df[['MonthlyCharges', 'gender']].groupby('gender').mean()
# Out:
#         MonthlyCharges
# gender
# Female       65.216652
# Male         64.387546

# %%
df[['MonthlyCharges', 'gender']].groupby('Contract').mean()
### Ketika melakukan Subsetting dan groupby
## Kolom yg digunakan untuk grouping harus termasuk dalam subset
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df[['MonthlyCharges', 'gender']].groupby('Contract').mean()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
df[['gender', 'tenure']].groupby('gender').median()
# Out:
#         tenure
# gender
# Female    29.0
# Male      29.0

# %%
df[['Contract', 'tenure']].groupby('Contract').mean()
# Out:
#                    tenure
# Contract
# Month-to-month  18.036645
# One year        42.073370
# Two year        57.071810

# %%
df[['Contract', 'MonthlyCharges']].groupby('Contract').mean().round(2).sort_values('MonthlyCharges', ascending=False)
# Out:
#                 MonthlyCharges
# Contract
# Month-to-month           66.40
# One year                 65.08
# Two year                 60.87

# %%
df[['Contract', 'MonthlyCharges']].groupby('Contract').mean().round(2).sort_values('Contract', ascending=False)
# Out:
#                 MonthlyCharges
# Contract
# Two year                 60.87
# One year                 65.08
# Month-to-month           66.40

# %%
df[['Contract', 'MonthlyCharges']].groupby('Contract').mean().round(2).sort_values('Contract', ascending=False).head(2)
# Out:
#           MonthlyCharges
# Contract
# Two year           60.87
# One year           65.08

# %%
df[['Contract', 'gender', 'tenure']].groupby(['Contract', 'gender']).mean()
# Out:
#                           tenure
# Contract       gender
# Month-to-month Female  17.974026
#                Male    18.098462
# One year       Female  42.445682
#                Male    41.718833
# Two year       Female  56.420238
#                Male    57.719527

# %%
df.pivot_table(index=['Contract', 'gender'], values='tenure')
# Out:
#                           tenure
# Contract       gender
# Month-to-month Female  17.974026
#                Male    18.098462
# One year       Female  42.445682
#                Male    41.718833
# Two year       Female  56.420238
#                Male    57.719527

# %%
pd.crosstab(index=[df['Contract'], df['gender']], columns='tenure', values=df['tenure'], aggfunc='mean')
# Out:
# col_0                     tenure
# Contract       gender
# Month-to-month Female  17.974026
#                Male    18.098462
# One year       Female  42.445682
#                Male    41.718833
# Two year       Female  56.420238
#                Male    57.719527

# %%
df[['Contract', 'gender', 'tenure']].groupby(['Contract', 'gender']).mean()
# Out:
#                           tenure
# Contract       gender
# Month-to-month Female  17.974026
#                Male    18.098462
# One year       Female  42.445682
#                Male    41.718833
# Two year       Female  56.420238
#                Male    57.719527

# %%
df[['Contract', 'gender', 'tenure']].groupby(['Contract', 'gender'], as_index=False).mean()
# Out:
#          Contract  gender     tenure
# 0  Month-to-month  Female  17.974026
# 1  Month-to-month    Male  18.098462
# 2        One year  Female  42.445682
# 3        One year    Male  41.718833
# 4        Two year  Female  56.420238
# 5        Two year    Male  57.719527

# %%
df[['Contract', 'tenure']].groupby('Contract').agg(['count', 'mean'])
# Out:
#                tenure
#                 count       mean
# Contract
# Month-to-month   3875  18.036645
# One year         1472  42.073370
# Two year         1685  57.071810

# %%
df.pivot_table(index='Contract', values='tenure',aggfunc=('count', 'mean'))
# Out:
#                 count       mean
# Contract
# Month-to-month   3875  18.036645
# One year         1472  42.073370
# Two year         1685  57.071810

# %%
df.pivot_table(index='Contract', values=['tenure', 'MonthlyCharges'],aggfunc=('count', 'mean'))
# Out:
#                MonthlyCharges            tenure
#                         count       mean  count       mean
# Contract
# Month-to-month           3875  66.398490   3875  18.036645
# One year                 1472  65.079416   1472  42.073370
# Two year                 1685  60.872374   1685  57.071810

# %%
df[['Contract', 'tenure', 'MonthlyCharges']].groupby('Contract').agg(['count', 'mean'])
# Out:
#                tenure            MonthlyCharges
#                 count       mean          count       mean
# Contract
# Month-to-month   3875  18.036645           3875  66.398490
# One year         1472  42.073370           1472  65.079416
# Two year         1685  57.071810           1685  60.872374

# %%
df[['Contract', 'tenure', 'MonthlyCharges', 'gender']].groupby(['Contract', 'gender']).agg(['median', 'mean'])
# Out:
#                       tenure            MonthlyCharges
#                       median       mean         median       mean
# Contract       gender
# Month-to-month Female   12.0  17.974026         73.800  66.652623
#                Male     12.0  18.098462         72.525  66.147615
# One year       Female   46.0  42.445682         70.125  66.841643
#                Male     43.0  41.718833         65.625  63.401326
# Two year       Female   64.0  56.420238         64.075  60.536905
#                Male     65.0  57.719527         64.950  61.205858

# %%
df.pivot_table(index=['Contract', 'gender'], values=['tenure', 'MonthlyCharges'],aggfunc=('count', 'mean'))
# Out:
#                       MonthlyCharges            tenure
#                                count       mean  count       mean
# Contract       gender
# Month-to-month Female           1925  66.652623   1925  17.974026
#                Male             1950  66.147615   1950  18.098462
# One year       Female            718  66.841643    718  42.445682
#                Male              754  63.401326    754  41.718833
# Two year       Female            840  60.536905    840  56.420238
#                Male              845  61.205858    845  57.719527

# %%
df[['Contract', 'tenure', 'MonthlyCharges', 'gender']].groupby(['Contract', 
                                                                'gender']).agg({'tenure' : 'mean', 'MonthlyCharges' : 'median'})
# Out:
#                           tenure  MonthlyCharges
# Contract       gender
# Month-to-month Female  17.974026          73.800
#                Male    18.098462          72.525
# One year       Female  42.445682          70.125
#                Male    41.718833          65.625
# Two year       Female  56.420238          64.075
#                Male    57.719527          64.950

# %%
df.pivot_table(index=['Contract', 'gender'], values=['tenure', 'MonthlyCharges'], aggfunc={'tenure' : 'mean', 
                                                                                          'MonthlyCharges' : 'median'})
# Out:
#                        MonthlyCharges     tenure
# Contract       gender
# Month-to-month Female          73.800  17.974026
#                Male            72.525  18.098462
# One year       Female          70.125  42.445682
#                Male            65.625  41.718833
# Two year       Female          64.075  56.420238
#                Male            64.950  57.719527

# %%
df[['Contract', 'tenure', 'MonthlyCharges', 'gender']].groupby(['Contract', 
                                                                'gender']).agg({'tenure' : ('mean', 'count'), 'MonthlyCharges' : 'median'})
# Out:
#                           tenure       MonthlyCharges
#                             mean count         median
# Contract       gender
# Month-to-month Female  17.974026  1925         73.800
#                Male    18.098462  1950         72.525
# One year       Female  42.445682   718         70.125
#                Male    41.718833   754         65.625
# Two year       Female  56.420238   840         64.075
#                Male    57.719527   845         64.950

# %%
df.pivot_table(index=['Contract', 'gender'], values=['tenure', 'MonthlyCharges'], aggfunc={'tenure' : ('mean', 'count'), 
                                                                                          'MonthlyCharges' : 'median'})
# Out:
#                       MonthlyCharges tenure
#                               median  count       mean
# Contract       gender
# Month-to-month Female         73.800   1925  17.974026
#                Male           72.525   1950  18.098462
# One year       Female         70.125    718  42.445682
#                Male           65.625    754  41.718833
# Two year       Female         64.075    840  56.420238
#                Male           64.950    845  57.719527

# %%
df[['Contract', 'tenure', 'MonthlyCharges', 'gender', 'TotalCharges']].groupby(['Contract', 
                                                                'gender']).agg({'tenure' : ('mean', 'count'), 'MonthlyCharges' : 'median',
                                                                               'TotalCharges' : 'sum'})
# Out:
#                           tenure       MonthlyCharges TotalCharges
#                             mean count         median          sum
# Contract       gender
# Month-to-month Female  17.974026  1925         73.800    2605975.8
#                Male    18.098462  1950         72.525    2699885.7
# One year       Female  42.445682   718         70.125    2248225.9
#                Male    41.718833   754         65.625    2218827.6
# Two year       Female  56.420238   840         64.075    3098152.5
#                Male    57.719527   845         64.950    3185101.2

# %%
df.pivot_table(index=['Contract', 'gender'], values=['tenure', 'MonthlyCharges', 'TotalCharges'], aggfunc={'tenure' : ('mean', 'count'), 
                                                                                          'MonthlyCharges' : 'median',
                                                                                                          'TotalCharges' : 'sum'})
# Out:
#                       MonthlyCharges TotalCharges tenure
#                               median          sum  count       mean
# Contract       gender
# Month-to-month Female         73.800    2605975.8   1925  17.974026
#                Male           72.525    2699885.7   1950  18.098462
# One year       Female         70.125    2248225.9    718  42.445682
#                Male           65.625    2218827.6    754  41.718833
# Two year       Female         64.075    3098152.5    840  56.420238
#                Male           64.950    3185101.2    845  57.719527
